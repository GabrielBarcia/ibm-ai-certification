# %% [markdown]
# <a href="https://cognitiveclass.ai"><img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DL0101EN-SkillsNetwork/images/IDSN-logo.png" width="400"> </a>
#
# # BackPropagation
#
# Estimated time needed: **30** mins

# %% [markdown]
# Backpropagation is the key algorithm used for training neural networks, allowing them to learn from data. It is based on the gradient descent optimization technique and works by iteratively adjusting the weights and biases of the network to minimize the error between the predicted and actual outputs.
#  In this lab, we will create a neural network to implement backpropagation for a XOR problem.

# %% [markdown]
# # Objective for this notebook
#
# * Train a Neural Network to Solve the XOR Problem
# * Implement Backpropagation for Neural Network Training
# * Demonstrate the Use of Activation Functions
# * Understand the Learning Process Over Multiple Epochs
# * Demonstrate Weight and Bias Adjustments via Gradient Descent
# * Evaluate the Model's Performance After Training
# * Monitor and Analyze the Training Process

# %% [markdown]
# <h2>Table of Contents</h2>
#
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 4>
# 1. <a href="#Import-Required-Libraries">Import Required Libraries</a><br>
# 2. <a href="#Initialize-Inputs">Initialize Inputs</a><br>
# 3. <a href="#Declare-the-network-parameters">Declare the network parameters</a><br>
# 4. <a href="#Define-the-weights">Define the weights</a><br>
# 5. <a href="#Training-the-Neural-Network">Training the Neural Network</a><br>
# 6. <a href="#Testing-the-Network">Testing the Network</a><br>
# 7. <a href="#Plot-the-error">Plot the error</a><br>
#
# </font>
# </div>

# %%
# All Libraries required for this lab are listed below. The libraries pre-installed on Skills Network Labs are commented. 
# If you run this notebook on a different environment, e.g., your desktop, you may need to uncomment and install certain libraries.

#!pip install numpy==1.26.4
#!pip install matplotlib==3.5.2

# %% [markdown]
# ## Import Required Libraries

# %%
# Importing the required library
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Initialize Inputs
# Define the input and expected output for a XOR gate problem

# %%
# Defining inputs and expected output (XOR truth table)
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]]).T  # 2x4 matrix, each column is a training example
d = np.array([0, 1, 1, 0])  # Expected output for XOR

# %% [markdown]
# # Declare the network parameters & the weights
#
# Define the network parameters such as
# 1. number of input neurons
# 2. hidden layer neurons
# 3. output neurons
# 4. learning rate
# 5. number of epochs
#
# Also, Declare the weights for the neurons. The initial weights are taken as random numbers which are then optimized by the backpropagation algorithm inside a function parameter `initialize_network_parameters()`

# %%
def initialize_network_parameters():
    # Network parameters
    inputSize = 2      # Number of input neurons (x1, x2)
    hiddenSize = 2     # Number of hidden neurons
    outputSize = 1     # Number of output neurons
    lr = 0.1           # Learning rate
    epochs = 180000    # Number of training epochs

    # Initialize weights and biases randomly within the range [-1, 1]
    w1 = np.random.rand(hiddenSize, inputSize) * 2 - 1  # Weights from input to hidden layer
    b1 = np.random.rand(hiddenSize, 1) * 2 - 1          # Bias for hidden layer
    w2 = np.random.rand(outputSize, hiddenSize) * 2 - 1 # Weights from hidden to output layer
    b2 = np.random.rand(outputSize, 1) * 2 - 1          # Bias for output layer

    return w1, b1, w2, b2, lr, epochs

# %% [markdown]
# ## Training the Neural Network
#
# The neural network works in 5 stages:
# 1. Forward pass
#     * The input **X** is multiplied by the weights **w1** and passed through the first layer, followed by the application of the sigmoid or ReLU activation function. This gives the output for the hidden layer.
#     * The output of the hidden layer is then passed through the second set of weights **w2** to compute the final output. Again, a sigmoid activation function is used to generate the final output **a2**.
#
# 2. Error calculation
#     * The error is computed as the difference between the expected output **(d)** and the actual output **(a2)**.
# 3. Backward pass
#     * **Output Layer**: The derivative of the sigmoid activation function is applied to the error, producing the gradient for the output layer **(da2)**. This is used to calculate how much the weights in the output layer need to be adjusted.
#     * **Hidden Layer**: The error is then propagated backward to the hidden layer. The gradient at the hidden layer **(da1)** is computed by taking the dot product of the transpose of the weights **(w2.T)** and the gradient from the output layer. The derivative of the activation function (sigmoid or ReLU) is used to adjust this error.
# 4. Weights and bias updates
#     * After computing the **gradients (dz1, dz2)**, the **weights (w1, w2)** and **biases (b1, b2)** are updated using the **learning rate (lr)** and **the gradients**. The updates are done to minimize the error and improve the model’s predictions.
# 5. Training:
#     * This entire process is repeated over many iterations **(epochs)**. During each epoch, the model adjusts its weights and biases to reduce the error. Over time, the network learns to approximate the XOR function.
# Forward Pass:

# %%
# Get initialized parameters
w1, b1, w2, b2, lr, epochs = initialize_network_parameters()

# Training the network using backpropagation
error_list = []
for epoch in range(epochs):
    # Forward pass
    z1 = np.dot(w1, X) + b1  # Weighted sum for hidden layer
    a1 = 1 / (1 + np.exp(-z1))  # Sigmoid activation for hidden layer

    z2 = np.dot(w2, a1) + b2  # Weighted sum for output layer
    a2 = 1 / (1 + np.exp(-z2))  # Sigmoid activation for output layer

    # Error calculation and backpropagation
    error = d - a2  # Difference between expected and actual output
    da2 = error * (a2 * (1 - a2))  # Derivative for output layer
    dz2 = da2  # Gradient for output layer

    # Propagate error to hidden layer
    da1 = np.dot(w2.T, dz2)  # Gradient for hidden layer
    dz1 = da1 * (a1 * (1 - a1))  # Derivative for hidden layer

    # Update weights and biases
    w2 += lr * np.dot(dz2, a1.T)  # Update weights from hidden to output layer
    b2 += lr * np.sum(dz2, axis=1, keepdims=True)  # Update bias for output layer

    w1 += lr * np.dot(dz1, X.T)  # Update weights from input to hidden layer
    b1 += lr * np.sum(dz1, axis=1, keepdims=True)  # Update bias for hidden layer
    if (epoch+1)%10000 == 0:
        print("Epoch: %d, Average error: %0.05f"%(epoch, np.average(abs(error))))
        error_list.append(np.average(abs(error)))
# Out:
# Epoch: 9999, Average error: 0.49997
# Epoch: 19999, Average error: 0.49976
# Epoch: 29999, Average error: 0.06651
# Epoch: 39999, Average error: 0.03316
# Epoch: 49999, Average error: 0.02464
# Epoch: 59999, Average error: 0.02039
# Epoch: 69999, Average error: 0.01774
# Epoch: 79999, Average error: 0.01589
# Epoch: 89999, Average error: 0.01451
# Epoch: 99999, Average error: 0.01343
# Epoch: 109999, Average error: 0.01256
# Epoch: 119999, Average error: 0.01183
# Epoch: 129999, Average error: 0.01122
# Epoch: 139999, Average error: 0.01069
# Epoch: 149999, Average error: 0.01023
# Epoch: 159999, Average error: 0.00982
# Epoch: 169999, Average error: 0.00945
# Epoch: 179999, Average error: 0.00913

# %% [markdown]
# ## Testing the Network
# After training, you can now test the neural network to verify that it has learned the XOR function and outputs the correct values close to [0, 1, 1, 0]

# %%
# Testing the trained network
z1 = np.dot(w1, X) + b1  # Weighted sum for hidden layer
a1 = 1 / (1 + np.exp(-z1))  # Sigmoid activation for hidden layer

z2 = np.dot(w2, a1) + b2  # Weighted sum for output layer
a2 = 1 / (1 + np.exp(-z2))  # Sigmoid activation for output layer

# Print results
print('Final output after training:', a2)
print('Ground truth', d)
print('Error after training:', error)
print('Average error: %0.05f'%np.average(abs(error)))
# Out:
# Final output after training: [[0.00842122 0.99129016 0.99129031 0.01066991]]
# Ground truth [0 1 1 0]
# Error after training: [[-0.00842124  0.00870987  0.00870972 -0.01066995]]
# Average error: 0.00913

# %% [markdown]
# ## Plot the error
# Here, we plot the error as a function of epochs. This shows how error changed over multiple iterations of forward and backward passes and how the network learnt over time

# %%
# Plot error
plt.plot(error_list)
plt.title('Error')
plt.xlabel('Epochs')
plt.ylabel('Error')
plt.show()

# %% [markdown]
# # Practice exercise 1

# %% [markdown]
# Implement backpropagation for **AND problem** using similar input as used for XOR problem above and plot the error

# %%
# Defining inputs and expected output (XOR truth table)
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]]).T  # 2x4 matrix, each column is a training example
d = np.array([1, 0, 0, 1])  # Expected output for XOR

# Write your code here
# Get initialized parameters
w1, b1, w2, b2, lr, epochs = initialize_network_parameters()

# Training the network using backpropagation
error_list = []
for epoch in range(epochs):
    # Forward pass
    z1 = np.dot(w1, X) + b1  # Weighted sum for hidden layer
    a1 = 1 / (1 + np.exp(-z1))  # Sigmoid activation for hidden layer

    z2 = np.dot(w2, a1) + b2  # Weighted sum for output layer
    a2 = 1 / (1 + np.exp(-z2))  # Sigmoid activation for output layer

    # Error calculation and backpropagation
    error = d - a2  # Difference between expected and actual output
    da2 = error * (a2 * (1 - a2))  # Derivative for output layer
    dz2 = da2  # Gradient for output layer

    # Propagate error to hidden layer
    da1 = np.dot(w2.T, dz2)  # Gradient for hidden layer
    dz1 = da1 * (a1 * (1 - a1))  # Derivative for hidden layer

    # Update weights and biases
    w2 += lr * np.dot(dz2, a1.T)  # Update weights from hidden to output layer
    b2 += lr * np.sum(dz2, axis=1, keepdims=True)  # Update bias for output layer

    w1 += lr * np.dot(dz1, X.T)  # Update weights from input to hidden layer
    b1 += lr * np.sum(dz1, axis=1, keepdims=True)  # Update bias for hidden layer
    if (epoch+1)%10000 == 0:
        print("Epoch: %d, Average error: %0.05f"%(epoch, np.average(abs(error))))
        error_list.append(np.average(abs(error)))


# Testing the trained network
z1 = np.dot(w1, X) + b1  # Weighted sum for hidden layer
a1 = 1 / (1 + np.exp(-z1))  # Sigmoid activation for hidden layer

z2 = np.dot(w2, a1) + b2  # Weighted sum for output layer
a2 = 1 / (1 + np.exp(-z2))  # Sigmoid activation for output layer

# Print results
print('Final output after training:', a2)
print('Ground truth', d)
print('Error after training:', error)
print('Average error: %0.05f'%np.average(abs(error)))
# Out:
# Epoch: 9999, Average error: 0.05015
# Epoch: 19999, Average error: 0.03000
# Epoch: 29999, Average error: 0.02317
# Epoch: 39999, Average error: 0.01949
# Epoch: 49999, Average error: 0.01712
# Epoch: 59999, Average error: 0.01543
# Epoch: 69999, Average error: 0.01415
# Epoch: 79999, Average error: 0.01314
# Epoch: 89999, Average error: 0.01231
# Epoch: 99999, Average error: 0.01162
# Epoch: 109999, Average error: 0.01103
# Epoch: 119999, Average error: 0.01053
# Epoch: 129999, Average error: 0.01008
# Epoch: 139999, Average error: 0.00969
# Epoch: 149999, Average error: 0.00934
# Epoch: 159999, Average error: 0.00902
# Epoch: 169999, Average error: 0.00873
# Epoch: 179999, Average error: 0.00847
# Final output after training: [[0.99050833 0.00806944 0.00806884 0.99174108]]
# Ground truth [1 0 0 1]
# Error after training: [[ 0.00949169 -0.00806947 -0.00806886  0.00825894]]
# Average error: 0.00847

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- Your answer is below:
#
#
# X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]]).T  # 2x4 matrix, each column is a training example
# d = np.array([0, 0, 0, 1])  # Expected output for AND
#
# # Get initialized parameters
# w1, b1, w2, b2, lr, epochs = initialize_network_parameters()
#
# # Training the network using backpropagation
# error_list = []
# for epoch in range(epochs):
#     # Forward pass
#     z1 = np.dot(w1, X) + b1  # Weighted sum for hidden layer
#     a1 = 1 / (1 + np.exp(-z1))  # Sigmoid activation for hidden layer
#
#     z2 = np.dot(w2, a1) + b2  # Weighted sum for output layer
#     a2 = 1 / (1 + np.exp(-z2))  # Sigmoid activation for output layer
#
#     # Error calculation and backpropagation
#     error = d - a2  # Difference between expected and actual output
#     da2 = error * (a2 * (1 - a2))  # Derivative for output layer
#     dz2 = da2  # Gradient for output layer
#
#     # Propagate error to hidden layer
#     da1 = np.dot(w2.T, dz2)  # Gradient for hidden layer
#     dz1 = da1 * (a1 * (1 - a1))  # Derivative for hidden layer
#
#     # Update weights and biases
#     w2 += lr * np.dot(dz2, a1.T)  # Update weights from hidden to output layer
#     b2 += lr * np.sum(dz2, axis=1, keepdims=True)  # Update bias for output layer
#
#     w1 += lr * np.dot(dz1, X.T)  # Update weights from input to hidden layer
#     b1 += lr * np.sum(dz1, axis=1, keepdims=True)  # Update bias for hidden layer
#     if (epoch+1)%10000 == 0:
#         print("Epoch: %d, Average error: %0.05f"%(epoch, np.average(abs(error))))
#         error_list.append(np.average(abs(error)))
#
#
# # Testing the trained network
# z1 = np.dot(w1, X) + b1  # Weighted sum for hidden layer
# a1 = 1 / (1 + np.exp(-z1))  # Sigmoid activation for hidden layer
#
# z2 = np.dot(w2, a1) + b2  # Weighted sum for output layer
# a2 = 1 / (1 + np.exp(-z2))  # Sigmoid activation for output layer
#
# # Print results
# print('\nFinal output after training:', a2)
# print('Ground truth', d)
# print('Error after training:', error)
# print('Average error: %0.05f'%np.average(abs(error)))
#
# # Plot error
# plt.plot(error_list)
# plt.title('Error')
# plt.xlabel('Epochs')
# plt.ylabel('Error')
# plt.show()
#
#
# -->

# %% [markdown]
# # Practice exercise 2

# %% [markdown]
# Now, decrease the learning rate to 0.01 and increase the number of epochs to 1000000 and check the error for XOR gate

# %%
# Write your code here

def initialize_network_parameters():
    # Network parameters
    inputSize = 2      # Number of input neurons (x1, x2)
    hiddenSize = 2     # Number of hidden neurons
    outputSize = 1     # Number of output neurons
    lr = 0.01           # Learning rate
    epochs = 1000000    # Number of training epochs

    # Initialize weights and biases randomly within the range [-1, 1]
    w1 = np.random.rand(hiddenSize, inputSize) * 2 - 1  # Weights from input to hidden layer
    b1 = np.random.rand(hiddenSize, 1) * 2 - 1          # Bias for hidden layer
    w2 = np.random.rand(outputSize, hiddenSize) * 2 - 1 # Weights from hidden to output layer
    b2 = np.random.rand(outputSize, 1) * 2 - 1          # Bias for output layer

    return w1, b1, w2, b2, lr, epochs

# Defining inputs and expected output (XOR truth table)
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]]).T  # 2x4 matrix, each column is a training example
d = np.array([0, 1, 1, 0])  # Expected output for XOR

# Write your code here
# Get initialized parameters
w1, b1, w2, b2, lr, epochs = initialize_network_parameters()

# Training the network using backpropagation
error_list = []
for epoch in range(epochs):
    # Forward pass
    z1 = np.dot(w1, X) + b1  # Weighted sum for hidden layer
    a1 = 1 / (1 + np.exp(-z1))  # Sigmoid activation for hidden layer

    z2 = np.dot(w2, a1) + b2  # Weighted sum for output layer
    a2 = 1 / (1 + np.exp(-z2))  # Sigmoid activation for output layer

    # Error calculation and backpropagation
    error = d - a2  # Difference between expected and actual output
    da2 = error * (a2 * (1 - a2))  # Derivative for output layer
    dz2 = da2  # Gradient for output layer

    # Propagate error to hidden layer
    da1 = np.dot(w2.T, dz2)  # Gradient for hidden layer
    dz1 = da1 * (a1 * (1 - a1))  # Derivative for hidden layer

    # Update weights and biases
    w2 += lr * np.dot(dz2, a1.T)  # Update weights from hidden to output layer
    b2 += lr * np.sum(dz2, axis=1, keepdims=True)  # Update bias for output layer

    w1 += lr * np.dot(dz1, X.T)  # Update weights from input to hidden layer
    b1 += lr * np.sum(dz1, axis=1, keepdims=True)  # Update bias for hidden layer
    if (epoch+1)%10000 == 0:
        print("Epoch: %d, Average error: %0.05f"%(epoch, np.average(abs(error))))
        error_list.append(np.average(abs(error)))


# Testing the trained network
z1 = np.dot(w1, X) + b1  # Weighted sum for hidden layer
a1 = 1 / (1 + np.exp(-z1))  # Sigmoid activation for hidden layer

z2 = np.dot(w2, a1) + b2  # Weighted sum for output layer
a2 = 1 / (1 + np.exp(-z2))  # Sigmoid activation for output layer

# Print results
print('Final output after training:', a2)
print('Ground truth', d)
print('Error after training:', error)
print('Average error: %0.05f'%np.average(abs(error)))
# Out:
# Epoch: 9999, Average error: 0.49464
# Epoch: 19999, Average error: 0.45568
# Epoch: 29999, Average error: 0.32848
# Epoch: 39999, Average error: 0.14861
# Epoch: 49999, Average error: 0.09983
# Epoch: 59999, Average error: 0.07849
# Epoch: 69999, Average error: 0.06622
# Epoch: 79999, Average error: 0.05811
# Epoch: 89999, Average error: 0.05227
# Epoch: 99999, Average error: 0.04782
# Epoch: 109999, Average error: 0.04430
# Epoch: 119999, Average error: 0.04142
# Epoch: 129999, Average error: 0.03902
# Epoch: 139999, Average error: 0.03698
# Epoch: 149999, Average error: 0.03522
# Epoch: 159999, Average error: 0.03368
# Epoch: 169999, Average error: 0.03231
# Epoch: 179999, Average error: 0.03110
# Epoch: 189999, Average error: 0.03000
# Epoch: 199999, Average error: 0.02902
# Epoch: 209999, Average error: 0.02812
# Epoch: 219999, Average error: 0.02729
# Epoch: 229999, Average error: 0.02653
# Epoch: 239999, Average error: 0.02583
# Epoch: 249999, Average error: 0.02518
# Epoch: 259999, Average error: 0.02458
# Epoch: 269999, Average error: 0.02402
# Epoch: 279999, Average error: 0.02349
# Epoch: 289999, Average error: 0.02299
# Epoch: 299999, Average error: 0.02253
# Epoch: 309999, Average error: 0.02209
# Epoch: 319999, Average error: 0.02167
# Epoch: 329999, Average error: 0.02128
# Epoch: 339999, Average error: 0.02091
# Epoch: 349999, Average error: 0.02055
# Epoch: 359999, Average error: 0.02021
# Epoch: 369999, Average error: 0.01989
# Epoch: 379999, Average error: 0.01958
# Epoch: 389999, Average error: 0.01929
# Epoch: 399999, Average error: 0.01901
# Epoch: 409999, Average error: 0.01874
# Epoch: 419999, Average error: 0.01848
# Epoch: 429999, Average error: 0.01823
# Epoch: 439999, Average error: 0.01799
# Epoch: 449999, Average error: 0.01776
# Epoch: 459999, Average error: 0.01754
# Epoch: 469999, Average error: 0.01732
# Epoch: 479999, Average error: 0.01712
# Epoch: 489999, Average error: 0.01692
# Epoch: 499999, Average error: 0.01672
# Epoch: 509999, Average error: 0.01654
# Epoch: 519999, Average error: 0.01636
# Epoch: 529999, Average error: 0.01618
# Epoch: 539999, Average error: 0.01601
# Epoch: 549999, Average error: 0.01585
# Epoch: 559999, Average error: 0.01569
# Epoch: 569999, Average error: 0.01553
# Epoch: 579999, Average error: 0.01538
# Epoch: 589999, Average error: 0.01524
# Epoch: 599999, Average error: 0.01509
# Epoch: 609999, Average error: 0.01495
# Epoch: 619999, Average error: 0.01482
# Epoch: 629999, Average error: 0.01469
# Epoch: 639999, Average error: 0.01456
# Epoch: 649999, Average error: 0.01444
# Epoch: 659999, Average error: 0.01431
# Epoch: 669999, Average error: 0.01420
# Epoch: 679999, Average error: 0.01408
# Epoch: 689999, Average error: 0.01397
# Epoch: 699999, Average error: 0.01386
# Epoch: 709999, Average error: 0.01375
# Epoch: 719999, Average error: 0.01364
# Epoch: 729999, Average error: 0.01354
# Epoch: 739999, Average error: 0.01344
# Epoch: 749999, Average error: 0.01334
# Epoch: 759999, Average error: 0.01324
# Epoch: 769999, Average error: 0.01315
# Epoch: 779999, Average error: 0.01306
# Epoch: 789999, Average error: 0.01297
# Epoch: 799999, Average error: 0.01288
# Epoch: 809999, Average error: 0.01279
# Epoch: 819999, Average error: 0.01270
# Epoch: 829999, Average error: 0.01262
# Epoch: 839999, Average error: 0.01254
# Epoch: 849999, Average error: 0.01246
# Epoch: 859999, Average error: 0.01238
# Epoch: 869999, Average error: 0.01230
# Epoch: 879999, Average error: 0.01222
# Epoch: 889999, Average error: 0.01215
# Epoch: 899999, Average error: 0.01208
# Epoch: 909999, Average error: 0.01200
# Epoch: 919999, Average error: 0.01193
# Epoch: 929999, Average error: 0.01186
# Epoch: 939999, Average error: 0.01179
# Epoch: 949999, Average error: 0.01173
# Epoch: 959999, Average error: 0.01166
# Epoch: 969999, Average error: 0.01160
# Epoch: 979999, Average error: 0.01153
# Epoch: 989999, Average error: 0.01147
# Epoch: 999999, Average error: 0.01141
# Final output after training: [[0.01146108 0.98689772 0.9891586  0.01021978]]
# Ground truth [0 1 1 0]
# Error after training: [[-0.01146109  0.01310229  0.01084141 -0.01021978]]
# Average error: 0.01141

# %% [markdown]
# Double-click <b>here</b> for the solution.
#
# <!-- Your answer is below:
#
# lr = 0.01         # Learning rate
# epochs = 1000000   # Number of training epochs
#
#
# # Defining inputs and expected output (XOR truth table)
# X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]]).T  # 2x4 matrix, each column is a training example
# d = np.array([0, 1, 1, 0])  # Expected output for XOR
#
# # Get initialized parameters
# w1, b1, w2, b2, lr, epochs = initialize_network_parameters()
#
# # Training the network using backpropagation
# error_list = []
# for epoch in range(epochs):
#     # Forward pass
#     z1 = np.dot(w1, X) + b1  # Weighted sum for hidden layer
#     a1 = 1 / (1 + np.exp(-z1))  # Sigmoid activation for hidden layer
#
#     z2 = np.dot(w2, a1) + b2  # Weighted sum for output layer
#     a2 = 1 / (1 + np.exp(-z2))  # Sigmoid activation for output layer
#
#     # Error calculation and backpropagation
#     error = d - a2  # Difference between expected and actual output
#     da2 = error * (a2 * (1 - a2))  # Derivative for output layer
#     dz2 = da2  # Gradient for output layer
#
#     # Propagate error to hidden layer
#     da1 = np.dot(w2.T, dz2)  # Gradient for hidden layer
#     dz1 = da1 * (a1 * (1 - a1))  # Derivative for hidden layer
#
#     # Update weights and biases
#     w2 += lr * np.dot(dz2, a1.T)  # Update weights from hidden to output layer
#     b2 += lr * np.sum(dz2, axis=1, keepdims=True)  # Update bias for output layer
#
#     w1 += lr * np.dot(dz1, X.T)  # Update weights from input to hidden layer
#     b1 += lr * np.sum(dz1, axis=1, keepdims=True)  # Update bias for hidden layer
#     if (epoch+1)%10000 == 0:
#         print("Epoch: %d, Average error: %0.05f"%(epoch, np.average(abs(error))))
#         error_list.append(np.average(abs(error)))
#
#
# # Testing the trained network
# z1 = np.dot(w1, X) + b1  # Weighted sum for hidden layer
# a1 = 1 / (1 + np.exp(-z1))  # Sigmoid activation for hidden layer
#
# z2 = np.dot(w2, a1) + b2  # Weighted sum for output layer
# a2 = 1 / (1 + np.exp(-z2))  # Sigmoid activation for output layer
#
# # Print results
# print('\nFinal output after training:', a2)
# print('Ground truth', d)
# print('Error after training:', error)
# print('Average error: %0.05f'%np.average(abs(error)))
#
#
# # Plot error
# plt.plot(error_list)
# plt.title('Error')
# plt.xlabel('Epochs')
# plt.ylabel('Error')
# plt.show()
#
#
# -->

# %% [markdown]
# ## Thank you for completing this lab!
#
# This notebook was created by [Aman Aggarwal](https://www.linkedin.com/in/aggarwal-aman/). I hope you found this lab interesting and educational. Feel free to contact me if you have any questions!

# %% [markdown]
# <!--
# ## Change Log
#
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2024-11-20  | 1.0  | Aman  |  Created the lab |
# <hr>
#
# ## <h3 align="center"> © IBM Corporation. All rights reserved. <h3/>

# %% [markdown]
# ## <h3 align="center"> &#169; IBM Corporation. All rights reserved. <h3/>
